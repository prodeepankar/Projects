# %% [markdown]
# <a href="https://colab.research.google.com/github/prodeepankar/Projects/blob/main/Deepankar_Sharma_EDA_Capstone_Project_Play_Store_App_Review_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Welcome!**
# The respective project is based on the Data Set provided by AlmaBetter on Google Play Store.
# The idea of the project is drive out meaningful insights from the Data for business to maximise their growth and reduce their expenses

# %% [markdown]
# ## **Project Description**
# ## The Play Store apps data has enormous potential to drive app-making businesses to success. Actionable insights can be drawn for developers to work on and capture the Android market.Each app (row) has values for catergory, rating, size, and more. Another dataset contains customer reviews of the android apps.
# ### **Problem Statement**
# Explore and analyze the data to discover key factors responsible for app engagement and success.

# %% [markdown]
# The Data set will be analyzed using Python language as the language provides great tools for analysis through its plethora of libraries.
#
# For various purposes, we will be using different libraries -
#
# 1. Mathematical and statistical purposes, we will use -
#
# *   Pandas library
# *   NumPy library
#
# 2. Visualisations and Plotting, will be done through -
#
# *   Matplotlib.Py library
# *   Seaborn library
#
# 3. Import Data Library
#
# *   OS
# *   Glob

# %% [markdown]
# # **Data Cleaning**
# A very important aspect of Data Analysis is Data Cleaning, since Data comes from various sources and alot of times, this data that we receive isn't cleaning.
#
# It contains missing values called as *null values* or NaN values, the best solution to such problem is to fill in these values from primary source but it is seldom possible, so we remove the null value Data and analyze.
#
# There also miss represented values that are completely out of context.
#
# For Ex - Presence of Date in genre column, in such cases also we drop values
#
# In some cases, where data can be replaced by a more common value, we replace it.
#
# For Ex - if Budget of certain movies are misrepresented, we replace those values with average value of movie budget in that Data Set

# %% [markdown]
# #**Data Analysis**
# Next step to Data cleaning is Data Analysis
#
# First, the required information is fetched for Data analysis, to understand better what data is saying.
#
# One has to be sure that during Data Analysis personal basis or personal experiences should not be taken into consideration as it can queston the credibility of analysis.
#
# However, Understanding of one's domain of knowledge is equally important to understand what data is trying to say.

# %% [markdown]
# # **Data Visualisation**
# *One picture is worth thousand words
#                -  Sir Albert Einstein*
# Visualisation is important point of contact between client and the analyst, these visualisations help us understand the Data better,simpler and faster.

# %%
# Importing Data set
from google.colab import drive 
drive.mount('/content/drive')
import pandas as pd
import numpy as np 
import os 
import glob
import matplotlib.pyplot as plt
import seaborn as sns
path_file = '/content/drive/MyDrive/AlmaBetter/data/Play Store App Review Analysis'
csv_file = glob.glob(os.path.join(path_file,"*.csv"))
# Out:
# Mounted at /content/drive

# %% [markdown]
# Since, the Data is a collection of multiple Data Set it is important for us, to see our Data. Thus, Here we have used glob module to Import all the dataset that were present inside the folder 'Data'.

# %% [markdown]
# Below, I have displayed all the Data sets that are present in inside the folder.

# %%
i = 1
lst = []
for f in csv_file:
  df= pd.read_csv(f)
  print(f"DATA SET - {i}")
  i += 1
  print(f.split('/')[-1])
  lst.append(f.split('/')[-1])
  display(df)
# Out:
# DATA SET - 1
# User Reviews.csv
#                                App  \
# 0            10 Best Foods for You
# 1            10 Best Foods for You
# 2            10 Best Foods for You
# 3            10 Best Foods for You
# 4            10 Best Foods for You
# ...                            ...
# 64290  Houzz Interior Design Ideas
# 64291  Houzz Interior Design Ideas
# 64292  Houzz Interior Design Ideas
# 64293  Houzz Interior Design Ideas
# 64294  Houzz Interior Design Ideas
#
#                                        Translated_Review Sentiment  \
# 0      I like eat delicious food. That's I'm cooking ...  Positive
# 1        This help eating healthy exercise regular basis  Positive
# 2                                                    NaN       NaN
# 3             Works great especially going grocery store  Positive
# 4                                           Best idea us  Positive
# ...                                                  ...       ...
# 64290                                                NaN       NaN
# 64291                                                NaN       NaN
# 64292                                                NaN       NaN
# 64293                                                NaN       NaN
# 64294                                                NaN       NaN
#
#        Sentiment_Polarity  Sentiment_Subjectivity
# 0                    1.00                0.533333
# 1                    0.25                0.288462
# 2                     NaN                     NaN
# 3                    0.40                0.875000
# 4                    1.00                0.300000
# ...                   ...                     ...
# 64290                 NaN                     NaN
# 64291                 NaN                     NaN
# 64292                 NaN                     NaN
# 64293                 NaN                     NaN
# 64294                 NaN                     NaN
#
# [64295 rows x 5 columns]
# DATA SET - 2
# Play Store Data.csv
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 0         4.1     159                 19M      10,000+  Free     0
# 1         3.9     967                 14M     500,000+  Free     0
# 2         4.7   87510                8.7M   5,000,000+  Free     0
# 3         4.5  215644                 25M  50,000,000+  Free     0
# 4         4.3     967                2.8M     100,000+  Free     0
# ...       ...     ...                 ...          ...   ...   ...
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating                     Genres      Last Updated  \
# 0           Everyone               Art & Design   January 7, 2018
# 1           Everyone  Art & Design;Pretend Play  January 15, 2018
# 2           Everyone               Art & Design    August 1, 2018
# 3               Teen               Art & Design      June 8, 2018
# 4           Everyone    Art & Design;Creativity     June 20, 2018
# ...              ...                        ...               ...
# 10836       Everyone                  Education     July 25, 2017
# 10837       Everyone                  Education      July 6, 2018
# 10838       Everyone                    Medical  January 20, 2017
# 10839     Mature 17+          Books & Reference  January 19, 2015
# 10840       Everyone                  Lifestyle     July 25, 2018
#
#               Current Ver         Android Ver
# 0                   1.0.0        4.0.3 and up
# 1                   2.0.0        4.0.3 and up
# 2                   1.2.4        4.0.3 and up
# 3      Varies with device          4.2 and up
# 4                     1.1          4.4 and up
# ...                   ...                 ...
# 10836                1.48          4.1 and up
# 10837                 1.0          4.1 and up
# 10838                 1.0          2.2 and up
# 10839  Varies with device  Varies with device
# 10840  Varies with device  Varies with device
#
# [10841 rows x 13 columns]

# %%
lst
# Out:
# ['User Reviews.csv', 'Play Store Data.csv']

# %% [markdown]
# The following are the columns of each Data Set -

# %%
Reviews_Set = pd.read_csv(path_file + '/' + lst[0])
PlayStore_Set = pd.read_csv(path_file + '/' + lst[1])

# %%
print(PlayStore_Set.columns)
print(Reviews_Set.columns)
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')
# Index(['App', 'Translated_Review', 'Sentiment', 'Sentiment_Polarity',
#        'Sentiment_Subjectivity'],
#       dtype='object')

# %% [markdown]
# Now, lets find out highest rated applications on PlayStore.

# %%
no_na_rating = PlayStore_Set.loc[~PlayStore_Set['Rating'].isna()]
no_na_rating.loc[no_na_rating['Rating'].idxmax()]
no_na_rating.loc[no_na_rating['Rating'] == 19] = no_na_rating['Rating'].median()
no_na_rating['Rating'].unique()
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# array([4.1, 3.9, 4.7, 4.5, 4.3, 4.4, 3.8, 4.2, 4.6, 3.2, 4. , 4.8, 4.9,
#        3.6, 3.7, 3.3, 3.4, 3.5, 3.1, 5. , 2.6, 3. , 1.9, 2.5, 2.8, 2.7,
#        1. , 2.9, 2.3, 2.2, 1.7, 2. , 1.8, 2.4, 1.6, 2.1, 1.4, 1.5, 1.2])

# %% [markdown]
# Since, you notice that there is a value equal to 19,this value is an *Outlier* such error can occur while documenting the data
#
# The best approach here is replace this value with the median value in the Data set

# %% [markdown]
# We are interested to know, that which application genre has highest average rating, since that shows

# %%
Highest_Avg_Rating=no_na_rating.groupby(['Category'])['Rating'].mean().reset_index().sort_values(by='Rating',ascending=False)
Highest_Avg_Rating=Highest_Avg_Rating[~(Highest_Avg_Rating['Category'] == 4.3)]
Highest_Avg_Rating
# Out:
#                Category    Rating
# 11               EVENTS  4.435556
# 9             EDUCATION  4.389032
# 1        ART_AND_DESIGN  4.358065
# 4   BOOKS_AND_REFERENCE  4.346067
# 24      PERSONALIZATION  4.335987
# 23            PARENTING  4.300000
# 15                 GAME  4.286326
# 3                BEAUTY  4.278571
# 16   HEALTH_AND_FITNESS  4.277104
# 27             SHOPPING  4.259664
# 28               SOCIAL  4.255598
# 33              WEATHER  4.244000
# 29               SPORTS  4.223511
# 26         PRODUCTIVITY  4.211396
# 17       HOUSE_AND_HOME  4.197368
# 12               FAMILY  4.192272
# 25          PHOTOGRAPHY  4.192114
# 2     AUTO_AND_VEHICLES  4.190411
# 21              MEDICAL  4.189143
# 18   LIBRARIES_AND_DEMO  4.178462
# 14       FOOD_AND_DRINK  4.166972
# 7         COMMUNICATION  4.158537
# 6                COMICS  4.155172
# 22   NEWS_AND_MAGAZINES  4.132189
# 13              FINANCE  4.131889
# 10        ENTERTAINMENT  4.126174
# 5              BUSINESS  4.121452
# 31     TRAVEL_AND_LOCAL  4.109292
# 19            LIFESTYLE  4.094904
# 32        VIDEO_PLAYERS  4.063750
# 20  MAPS_AND_NAVIGATION  4.051613
# 30                TOOLS  4.047411
# 8                DATING  3.970769

# %%
from matplotlib import rcParams
rcParams['figure.figsize'] = 20,10
Category_ = Highest_Avg_Rating['Category'].to_list()
print(Category_)
Category_list = [i[:3] for i in Category_]
print(Category_list)
Rating_list = Highest_Avg_Rating['Rating'].to_list()
Data_1=dict(zip(Category_list,Rating_list))
# Out:
# ['EVENTS', 'EDUCATION', 'ART_AND_DESIGN', 'BOOKS_AND_REFERENCE', 'PERSONALIZATION', 'PARENTING', 'GAME', 'BEAUTY', 'HEALTH_AND_FITNESS', 'SHOPPING', 'SOCIAL', 'WEATHER', 'SPORTS', 'PRODUCTIVITY', 'HOUSE_AND_HOME', 'FAMILY', 'PHOTOGRAPHY', 'AUTO_AND_VEHICLES', 'MEDICAL', 'LIBRARIES_AND_DEMO', 'FOOD_AND_DRINK', 'COMMUNICATION', 'COMICS', 'NEWS_AND_MAGAZINES', 'FINANCE', 'ENTERTAINMENT', 'BUSINESS', 'TRAVEL_AND_LOCAL', 'LIFESTYLE', 'VIDEO_PLAYERS', 'MAPS_AND_NAVIGATION', 'TOOLS', 'DATING']
# ['EVE', 'EDU', 'ART', 'BOO', 'PER', 'PAR', 'GAM', 'BEA', 'HEA', 'SHO', 'SOC', 'WEA', 'SPO', 'PRO', 'HOU', 'FAM', 'PHO', 'AUT', 'MED', 'LIB', 'FOO', 'COM', 'COM', 'NEW', 'FIN', 'ENT', 'BUS', 'TRA', 'LIF', 'VID', 'MAP', 'TOO', 'DAT']

# %%
grp_1 = sns.lineplot(data=Data_1).set(title='Mean Rating in different Categories')
sns.set(font_scale=1.0)

# %%
(no_na_rating.groupby(['Category'])['Rating'].mean()).reset_index().sort_values(by='Rating',ascending=False).head(3)
# Out:
#           Category    Rating
# 11          EVENTS  4.435556
# 9        EDUCATION  4.389032
# 1   ART_AND_DESIGN  4.358065

# %%
no_na_rating['Rating'].unique()
Rating_data = no_na_rating[['App','Rating']].reset_index(drop=True).drop_duplicates(subset='App')
Rating_Apps=Rating_data.groupby(['Rating']).count().reset_index().rename(columns = {'App':'No of Apps'})
Rating_Apps
# Out:
#     Rating  No of Apps
# 0      1.0          16
# 1      1.2           1
# 2      1.4           3
# 3      1.5           3
# 4      1.6           4
# 5      1.7           8
# 6      1.8           8
# 7      1.9          11
# 8      2.0          12
# 9      2.1           8
# 10     2.2          14
# 11     2.3          20
# 12     2.4          19
# 13     2.5          20
# 14     2.6          24
# 15     2.7          23
# 16     2.8          40
# 17     2.9          45
# 18     3.0          81
# 19     3.1          69
# 20     3.2          63
# 21     3.3         100
# 22     3.4         126
# 23     3.5         156
# 24     3.6         167
# 25     3.7         224
# 26     3.8         286
# 27     3.9         359
# 28     4.0         513
# 29     4.1         621
# 30     4.2         810
# 31     4.3         898
# 32     4.4         895
# 33     4.5         848
# 34     4.6         683
# 35     4.7         442
# 36     4.8         221
# 37     4.9          85
# 38     5.0         271

# %%
sns.stripplot(data=Rating_Apps,x='Rating',y='No of Apps',size=10).set(title="Rating Density of Apps")
sns.set(font_scale=1.5)

# %% [markdown]
# From observing Data above one can understand that most of applications are rated 4-4.6.
# Very less applications are either highly rated or lowly rated.

# %% [markdown]
# In order to understand the market better, we need to which Category of Apps are dominant in the market.

# %%
PlayStore_Set=PlayStore_Set.loc[~(PlayStore_Set['Category'] == '1.9')]
PlayStore_Set.groupby('Category')['App'].count().reset_index()
Category_Count_Frame = PlayStore_Set.groupby('Category')['App'].count().reset_index()
print(Category_Count_Frame)
total_no_of_apps = Category_Count_Frame.sum()
total_no_of_apps
# Out:
#                Category   App
# 0        ART_AND_DESIGN    65
# 1     AUTO_AND_VEHICLES    85
# 2                BEAUTY    53
# 3   BOOKS_AND_REFERENCE   231
# 4              BUSINESS   460
# 5                COMICS    60
# 6         COMMUNICATION   387
# 7                DATING   234
# 8             EDUCATION   156
# 9         ENTERTAINMENT   149
# 10               EVENTS    64
# 11               FAMILY  1972
# 12              FINANCE   366
# 13       FOOD_AND_DRINK   127
# 14                 GAME  1144
# 15   HEALTH_AND_FITNESS   341
# 16       HOUSE_AND_HOME    88
# 17   LIBRARIES_AND_DEMO    85
# 18            LIFESTYLE   382
# 19  MAPS_AND_NAVIGATION   137
# 20              MEDICAL   463
# 21   NEWS_AND_MAGAZINES   283
# 22            PARENTING    60
# 23      PERSONALIZATION   392
# 24          PHOTOGRAPHY   335
# 25         PRODUCTIVITY   424
# 26             SHOPPING   260
# 27               SOCIAL   295
# 28               SPORTS   384
# 29                TOOLS   843
# 30     TRAVEL_AND_LOCAL   258
# 31        VIDEO_PLAYERS   175
# 32              WEATHER    82
# Category    ART_AND_DESIGNAUTO_AND_VEHICLESBEAUTYBOOKS_AND...
# App                                                     10840
# dtype: object

# %%
# Now, we will create a function of percentage of the Category
def percentage_app(apps):
   x = (apps/10840)*100
   return x

# %%
Category_Count_Frame['Percentage'] = Category_Count_Frame.apply(lambda x: percentage_app(x['App']),axis=1)
Category_Count_Frame.sort_values(by='Percentage',ascending=False)
sns.barplot(data=Category_Count_Frame.sort_values(by='Percentage',ascending=False).head(5),x='Category',y='Percentage').set(title='Highest Percentage Applications on Playstore')
# Out:
# [Text(0.5, 1.0, 'Highest Percentage Applications on Playstore')]

# %% [markdown]
# Here, we can aggregate these values and find out the category with **maximum highest ratings**.

# %% [markdown]
# Here, one more thing to notice is that Rating is dependent quantity to reviews, we need understand the correlation between the **Rating** and **Review**, which gives us the true picture of the Data

# %%
type(no_na_rating['Reviews'][1])
# Out:
# str

# %%
def str_to_int(str):
  return int(str)

# %%
no_na_rating['Reviews'] = no_na_rating['Reviews'].apply(str_to_int)
print(type(no_na_rating['Reviews'][1]))
# Out:
# <class 'numpy.int64'>

# %% [markdown]
# Here, The values of **Reviews** is in String format, we will convert the Data from String format to Int format for the ease of analysis

# %%
## Removing the null or misrepresented values
no_na_rating[no_na_rating['Reviews'].isnull()]
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %% [markdown]
# So, our Data does not contain any null values for Reviews. Thus,we are good to go !!!!

# %% [markdown]
# Lets compare values Ratings V/s Reviews

# %%
no_na_rating[['App','Reviews','Rating']].sort_values(by=['Reviews','Rating'],ascending=False).drop_duplicates(subset='App').head(10).reset_index(drop=True)
# Out:
#                                                  App   Reviews  Rating
# 0                                           Facebook  78158306     4.1
# 1                                 WhatsApp Messenger  69119316     4.4
# 2                                          Instagram  66577446     4.5
# 3           Messenger – Text and Video Chat for Free  56646578     4.0
# 4                                     Clash of Clans  44893888     4.6
# 5            Clean Master- Space Cleaner & Antivirus  42916526     4.7
# 6                                     Subway Surfers  27725352     4.5
# 7                                            YouTube  25655305     4.3
# 8  Security Master - Antivirus, VPN, AppLock, Boo...  24900999     4.7
# 9                                       Clash Royale  23136735     4.6

# %% [markdown]
# On comparing values, our review vs rating we come across the top 20 actual applications.
# So, now we create a product of rating and review to understand with higher accuracy that what apps are actually being rated high with higher number of reviews.

# %%
PlayStore_Set['Reviews']
# Out:
# 0           159
# 1           967
# 2         87510
# 3        215644
# 4           967
#           ...
# 10836        38
# 10837         4
# 10838         3
# 10839       114
# 10840    398307
# Name: Reviews, Length: 10840, dtype: object

# %%
def Review_Rating(Rating,Reviews):
  product = Rating*Reviews
  return product

# %%
no_na_rating['Review_Rating'] = no_na_rating.apply(lambda x: Review_Rating(x['Reviews'],x['Rating']),axis=1)

# %% [markdown]
# **Top 10 Applications on Playstore**

# %%
Top_rated_App=no_na_rating.sort_values(by=['Review_Rating'],ascending=False).drop_duplicates(subset='App').head(10).reset_index(drop=True)
Top_rated_App
Top_rated_App[['App','Review_Rating']]
# Out:
#                                                  App  Review_Rating
# 0                                           Facebook    320449054.6
# 1                                 WhatsApp Messenger    304124990.4
# 2                                          Instagram    299598507.0
# 3           Messenger – Text and Video Chat for Free    226586312.0
# 4                                     Clash of Clans    206511884.8
# 5            Clean Master- Space Cleaner & Antivirus    201707672.2
# 6                                     Subway Surfers    124764084.0
# 7  Security Master - Antivirus, VPN, AppLock, Boo...    117034695.3
# 8                                            YouTube    110317811.5
# 9                                       Clash Royale    106428981.0

# %% [markdown]
# **Below given is the category-wise disturbution of Top 10 applications in the Playstore**

# %%
(Top_rated_App.drop_duplicates(subset='App').groupby(['Category'])['App']).count().reset_index().sort_values(by='App',ascending=False).head(10)
# Out:
#         Category  App
# 1           GAME    3
# 0  COMMUNICATION    2
# 2         SOCIAL    2
# 3          TOOLS    2
# 4  VIDEO_PLAYERS    1

# %%
# lets create acronyms
def create_acronyms(word):
  return word[:4]

# %%
Top_rated_App['Apps_Acronym'] = Top_rated_App.apply(lambda x: create_acronyms(x['App']),axis=1)
Top_rated_App
# Out:
#                                                  App       Category  Rating  \
# 0                                           Facebook         SOCIAL     4.1
# 1                                 WhatsApp Messenger  COMMUNICATION     4.4
# 2                                          Instagram         SOCIAL     4.5
# 3           Messenger – Text and Video Chat for Free  COMMUNICATION     4.0
# 4                                     Clash of Clans           GAME     4.6
# 5            Clean Master- Space Cleaner & Antivirus          TOOLS     4.7
# 6                                     Subway Surfers           GAME     4.5
# 7  Security Master - Antivirus, VPN, AppLock, Boo...          TOOLS     4.7
# 8                                            YouTube  VIDEO_PLAYERS     4.3
# 9                                       Clash Royale           GAME     4.6
#
#     Reviews                Size        Installs  Type Price Content Rating  \
# 0  78158306  Varies with device  1,000,000,000+  Free     0           Teen
# 1  69119316  Varies with device  1,000,000,000+  Free     0       Everyone
# 2  66577446  Varies with device  1,000,000,000+  Free     0           Teen
# 3  56646578  Varies with device  1,000,000,000+  Free     0       Everyone
# 4  44893888                 98M    100,000,000+  Free     0   Everyone 10+
# 5  42916526  Varies with device    500,000,000+  Free     0       Everyone
# 6  27725352                 76M  1,000,000,000+  Free     0   Everyone 10+
# 7  24900999  Varies with device    500,000,000+  Free     0       Everyone
# 8  25655305  Varies with device  1,000,000,000+  Free     0           Teen
# 9  23136735                 97M    100,000,000+  Free     0   Everyone 10+
#
#                     Genres    Last Updated         Current Ver  \
# 0                   Social  August 3, 2018  Varies with device
# 1            Communication  August 3, 2018  Varies with device
# 2                   Social   July 31, 2018  Varies with device
# 3            Communication  August 1, 2018  Varies with device
# 4                 Strategy   July 15, 2018           10.322.16
# 5                    Tools  August 3, 2018  Varies with device
# 6                   Arcade   July 12, 2018              1.90.0
# 7                    Tools  August 4, 2018               4.6.6
# 8  Video Players & Editors  August 2, 2018  Varies with device
# 9                 Strategy   June 27, 2018               2.3.2
#
#           Android Ver  Review_Rating Apps_Acronym
# 0  Varies with device    320449054.6         Face
# 1  Varies with device    304124990.4         What
# 2  Varies with device    299598507.0         Inst
# 3  Varies with device    226586312.0         Mess
# 4          4.1 and up    206511884.8         Clas
# 5  Varies with device    201707672.2         Clea
# 6          4.1 and up    124764084.0         Subw
# 7  Varies with device    117034695.3         Secu
# 8  Varies with device    110317811.5         YouT
# 9          4.1 and up    106428981.0         Clas

# %%
sns.relplot(data=Top_rated_App,y='Reviews',x='Apps_Acronym',hue='Category',size='Rating',height=10)

# %% [markdown]
# Now, we are interested in knowing the top application for each Category

# %%
no_na_rating = no_na_rating[~(no_na_rating['Category'] == 4.3)]

# %%
max_review_rating=no_na_rating.groupby(['Category'])['Review_Rating'].max().reset_index()
max_review_rating
# Out:
#                Category  Review_Rating
# 0        ART_AND_DESIGN      1299042.8
# 1     AUTO_AND_VEHICLES      1142064.0
# 2                BEAUTY       454860.0
# 3   BOOKS_AND_REFERENCE     13409869.4
# 4              BUSINESS      5520812.0
# 5                COMICS      4562748.0
# 6         COMMUNICATION    304124990.4
# 7                DATING      2067668.0
# 8             EDUCATION     29565382.9
# 9         ENTERTAINMENT     30811056.6
# 10               EVENTS       160452.0
# 11               FAMILY    206454656.2
# 12              FINANCE      6322925.4
# 13       FOOD_AND_DRINK      4854794.5
# 14                 GAME    206511884.8
# 15   HEALTH_AND_FITNESS     21885153.6
# 16       HOUSE_AND_HOME      1880581.5
# 17   LIBRARIES_AND_DEMO      1427956.9
# 18            LIFESTYLE     11159100.0
# 19  MAPS_AND_NAVIGATION     33270093.4
# 20              MEDICAL       735127.0
# 21   NEWS_AND_MAGAZINES     50169832.9
# 22            PARENTING      3093008.9
# 23      PERSONALIZATION     33592482.0
# 24          PHOTOGRAPHY     48865729.5
# 25         PRODUCTIVITY     24766331.0
# 26             SHOPPING     27954364.5
# 27               SOCIAL    320449054.6
# 28               SPORTS     63832095.0
# 29                TOOLS    201707672.2
# 30     TRAVEL_AND_LOCAL     39712103.9
# 31        VIDEO_PLAYERS    110317811.5
# 32              WEATHER     10434789.2

# %%
df = pd.DataFrame()

# %%
for index,i in max_review_rating.iterrows():
   df =df.append(no_na_rating.loc[no_na_rating['Review_Rating'] == max_review_rating['Review_Rating'][index]])

# %%
df = df.drop_duplicates(subset='App').reset_index(drop=True)
#df = df.drop(columns=['index'])

# %%
df
# Out:
#                                                   App             Category  \
# 0                          Textgram - write on photos       ART_AND_DESIGN
# 1       Android Auto - Maps, Media, Messaging & Voice    AUTO_AND_VEHICLES
# 2                       Beauty Camera - Selfie Camera               BEAUTY
# 3                                Wattpad 📖 Free Books  BOOKS_AND_REFERENCE
# 4                                         Uber Driver             BUSINESS
# 5                          LINE WEBTOON - Free Comics               COMICS
# 6                                  WhatsApp Messenger        COMMUNICATION
# 7                      Zoosk Dating App: Meet Singles               DATING
# 8                      Duolingo: Learn Languages Free            EDUCATION
# 9                                   Google Play Games        ENTERTAINMENT
# 10                         Ticketmaster Event Tickets               EVENTS
# 11                                     Clash of Clans               FAMILY
# 12                                       Chase Mobile              FINANCE
# 13                                 Domino's Pizza USA       FOOD_AND_DRINK
# 14  Period Tracker - Period Calendar Ovulation Tra...   HEALTH_AND_FITNESS
# 15  Zillow: Find Houses for Sale & Apartments for ...       HOUSE_AND_HOME
# 16                            MX Player Codec (ARMv7)   LIBRARIES_AND_DEMO
# 17                                             Tinder            LIFESTYLE
# 18  Waze - GPS, Maps, Traffic Alerts & Live Naviga...  MAPS_AND_NAVIGATION
# 19                       My Calendar - Period Tracker              MEDICAL
# 20                                            Twitter   NEWS_AND_MAGAZINES
# 21     Pregnancy Tracker & Countdown to Baby Due Date            PARENTING
# 22   GO Launcher - 3D parallax Themes & HD Wallpapers      PERSONALIZATION
# 23                                      Google Photos          PHOTOGRAPHY
# 24                      ES File Explorer File Manager         PRODUCTIVITY
# 25                           Wish - Shopping Made Fun             SHOPPING
# 26                                           Facebook               SOCIAL
# 27                                        8 Ball Pool               SPORTS
# 28            Clean Master- Space Cleaner & Antivirus                TOOLS
# 29                          Maps - Navigate & Explore     TRAVEL_AND_LOCAL
# 30                                            YouTube        VIDEO_PLAYERS
# 31                 Weather & Clock Widget for Android              WEATHER
#
#     Rating   Reviews                Size        Installs  Type Price  \
# 0      4.4    295237  Varies with device     10,000,000+  Free     0
# 1      4.2    271920                 16M     10,000,000+  Free     0
# 2      4.0    113715  Varies with device     10,000,000+  Free     0
# 3      4.6   2915189  Varies with device    100,000,000+  Free     0
# 4      4.4   1254730  Varies with device     10,000,000+  Free     0
# 5      4.5   1013944  Varies with device     10,000,000+  Free     0
# 6      4.4  69119316  Varies with device  1,000,000,000+  Free     0
# 7      4.0    516917  Varies with device     10,000,000+  Free     0
# 8      4.7   6290507  Varies with device    100,000,000+  Free     0
# 9      4.3   7165362  Varies with device  1,000,000,000+  Free     0
# 10     4.0     40113                 36M      5,000,000+  Free     0
# 11     4.6  44881447                 98M    100,000,000+  Free     0
# 12     4.6   1374549                 32M     10,000,000+  Free     0
# 13     4.7   1032935  Varies with device     10,000,000+  Free     0
# 14     4.8   4559407  Varies with device    100,000,000+  Free     0
# 15     4.5    417907                 34M     10,000,000+  Free     0
# 16     4.3    332083                6.3M     10,000,000+  Free     0
# 17     4.0   2789775                 68M    100,000,000+  Free     0
# 18     4.6   7232629  Varies with device    100,000,000+  Free     0
# 19     4.7    156410                 14M      5,000,000+  Free     0
# 20     4.3  11667403  Varies with device    500,000,000+  Free     0
# 21     4.7    658087                 62M     10,000,000+  Free     0
# 22     4.5   7464996  Varies with device    100,000,000+  Free     0
# 23     4.5  10859051  Varies with device  1,000,000,000+  Free     0
# 24     4.6   5383985                 16M    100,000,000+  Free     0
# 25     4.5   6212081                 15M    100,000,000+  Free     0
# 26     4.1  78158306  Varies with device  1,000,000,000+  Free     0
# 27     4.5  14184910                 52M    100,000,000+  Free     0
# 28     4.7  42916526  Varies with device    500,000,000+  Free     0
# 29     4.3   9235373  Varies with device  1,000,000,000+  Free     0
# 30     4.3  25655305  Varies with device  1,000,000,000+  Free     0
# 31     4.4   2371543                 11M     50,000,000+  Free     0
#
#    Content Rating                   Genres    Last Updated  \
# 0        Everyone             Art & Design   July 30, 2018
# 1            Teen          Auto & Vehicles   July 11, 2018
# 2        Everyone                   Beauty  August 3, 2017
# 3            Teen        Books & Reference  August 1, 2018
# 4        Everyone                 Business  August 3, 2018
# 5            Teen                   Comics   July 31, 2018
# 6        Everyone            Communication  August 3, 2018
# 7      Mature 17+                   Dating  August 2, 2018
# 8        Everyone      Education;Education  August 1, 2018
# 9            Teen            Entertainment   July 16, 2018
# 10       Everyone                   Events   July 23, 2018
# 11   Everyone 10+                 Strategy   July 15, 2018
# 12       Everyone                  Finance   July 23, 2018
# 13       Everyone             Food & Drink   July 20, 2018
# 14       Everyone         Health & Fitness  August 1, 2018
# 15       Everyone             House & Home  August 1, 2018
# 16       Everyone         Libraries & Demo  April 23, 2018
# 17     Mature 17+                Lifestyle  August 2, 2018
# 18       Everyone        Maps & Navigation   July 29, 2018
# 19       Everyone                  Medical  August 3, 2018
# 20     Mature 17+         News & Magazines  August 6, 2018
# 21       Everyone                Parenting    May 24, 2018
# 22       Everyone          Personalization  August 3, 2018
# 23       Everyone              Photography  August 6, 2018
# 24       Everyone             Productivity  August 3, 2018
# 25       Everyone                 Shopping  August 3, 2018
# 26           Teen                   Social  August 3, 2018
# 27       Everyone                   Sports   July 31, 2018
# 28       Everyone                    Tools  August 3, 2018
# 29       Everyone           Travel & Local   July 31, 2018
# 30           Teen  Video Players & Editors  August 2, 2018
# 31       Everyone                  Weather    June 4, 2018
#
#            Current Ver         Android Ver  Review_Rating
# 0   Varies with device  Varies with device      1299042.8
# 1   Varies with device          5.0 and up      1142064.0
# 2   Varies with device  Varies with device       454860.0
# 3   Varies with device  Varies with device     13409869.4
# 4   Varies with device  Varies with device      5520812.0
# 5   Varies with device  Varies with device      4562748.0
# 6   Varies with device  Varies with device    304124990.4
# 7   Varies with device  Varies with device      2067668.0
# 8   Varies with device  Varies with device     29565382.9
# 9   Varies with device  Varies with device     30811056.6
# 10  Varies with device  Varies with device       160452.0
# 11           10.322.16          4.1 and up    206454656.2
# 12                3.52          5.0 and up      6322925.4
# 13  Varies with device  Varies with device      4854794.5
# 14  Varies with device  Varies with device     21885153.6
# 15          9.8.1.7425          4.4 and up      1880581.5
# 16              1.9.19          4.0 and up      1427956.9
# 17               9.5.0          4.4 and up     11159100.0
# 18  Varies with device  Varies with device     33270093.4
# 19               5.9.6          4.1 and up       735127.0
# 20  Varies with device  Varies with device     50169832.9
# 21              3.15.1          5.0 and up      3093008.9
# 22  Varies with device  Varies with device     33592482.0
# 23  Varies with device  Varies with device     48865729.5
# 24           4.1.8.2.2          4.0 and up     24766331.0
# 25              4.20.5          4.1 and up     27954364.5
# 26  Varies with device  Varies with device    320449054.6
# 27               4.0.0        4.0.3 and up     63832095.0
# 28  Varies with device  Varies with device    201707672.2
# 29  Varies with device  Varies with device     39712103.9
# 30  Varies with device  Varies with device    110317811.5
# 31             5.9.4.0        4.0.3 and up     10434789.2

# %%
sns.stripplot(data=df,y='Category',x='Rating',size=10)

# %% [markdown]
# Another criteria to understand the success of an application is the number of user of that application.
#
# However, Instead of users we are provided with the number of installs
#
# lets find out the highest number of applications that are being installed.

# %%
def remove_plus(word):
  word = word.replace('+','').replace(',','')
  return word

# %%
int(remove_plus('10,+0'))
# Out:
# 100

# %%
PlayStore_Set['Installs'] = PlayStore_Set['Installs'].apply(remove_plus)
PlayStore_Set['Installs'] = PlayStore_Set['Installs'].apply(str_to_int)
Max_Installs=PlayStore_Set.sort_values(by='Installs',ascending=False).drop_duplicates(subset='App')

# %%
Max_Installs.head(200)
Max_Installs.head(10)
# Out:
#                                            App       Category  Rating  \
# 3896                            Subway Surfers           GAME     4.5
# 3943                                  Facebook         SOCIAL     4.1
# 335   Messenger – Text and Video Chat for Free  COMMUNICATION     4.0
# 3523                              Google Drive   PRODUCTIVITY     4.4
# 2884                             Google Photos    PHOTOGRAPHY     4.5
# 3665                                   YouTube  VIDEO_PLAYERS     4.3
# 4234             Skype - free IM & video calls  COMMUNICATION     4.1
# 3687                   Google Play Movies & TV  VIDEO_PLAYERS     3.7
# 4153                                  Hangouts  COMMUNICATION     4.0
# 4150                                    Google          TOOLS     4.4
#
#        Reviews                Size    Installs  Type Price Content Rating  \
# 3896  27711703                 76M  1000000000  Free     0   Everyone 10+
# 3943  78128208  Varies with device  1000000000  Free     0           Teen
# 335   56642847  Varies with device  1000000000  Free     0       Everyone
# 3523   2731211  Varies with device  1000000000  Free     0       Everyone
# 2884  10859051  Varies with device  1000000000  Free     0       Everyone
# 3665  25655305  Varies with device  1000000000  Free     0           Teen
# 4234  10484169  Varies with device  1000000000  Free     0       Everyone
# 3687    906384  Varies with device  1000000000  Free     0           Teen
# 4153   3419464  Varies with device  1000000000  Free     0       Everyone
# 4150   8021623  Varies with device  1000000000  Free     0       Everyone
#
#                        Genres    Last Updated         Current Ver  \
# 3896                   Arcade   July 12, 2018              1.90.0
# 3943                   Social  August 3, 2018  Varies with device
# 335             Communication  August 1, 2018  Varies with device
# 3523             Productivity  August 6, 2018  Varies with device
# 2884              Photography  August 6, 2018  Varies with device
# 3665  Video Players & Editors  August 2, 2018  Varies with device
# 4234            Communication  August 3, 2018  Varies with device
# 3687  Video Players & Editors  August 6, 2018  Varies with device
# 4153            Communication   July 21, 2018  Varies with device
# 4150                    Tools  August 3, 2018  Varies with device
#
#              Android Ver
# 3896          4.1 and up
# 3943  Varies with device
# 335   Varies with device
# 3523  Varies with device
# 2884  Varies with device
# 3665  Varies with device
# 4234  Varies with device
# 3687  Varies with device
# 4153  Varies with device
# 4150  Varies with device

# %%
sns.scatterplot(data=Max_Installs,y='Installs',x='Rating',hue='Type',size='Installs')

# %% [markdown]
# Now, lets try to understand the performance of paid applications

# %%
def remove_Dollar(word):
  word = word.replace('$','')
  return word
def str_to_ft(word):
  return float(word)

# %%
PlayStore_Set['Price'] = PlayStore_Set['Price'].apply(remove_Dollar)
PlayStore_Set['Price'] = PlayStore_Set['Price'].apply(str_to_ft)

# %%
Paid_Apps=PlayStore_Set.loc[PlayStore_Set['Type'] == 'Paid'].drop_duplicates(subset='App').reset_index(drop=True)
Paid_Apps.sort_values(by='Price',ascending=False)
# Out:
#                                 App         Category  Rating Reviews  Size  \
# 179        I'm Rich - Trump Edition        LIFESTYLE     3.6     275  7.3M
# 320              I AM RICH PRO PLUS          FINANCE     4.0      36   41M
# 178                      💎 I'm rich        LIFESTYLE     3.8     718   26M
# 318                       I am Rich          FINANCE     4.3     180  3.8M
# 315  I am rich (Most expensive app)          FINANCE     4.1     129  2.7M
# ..                              ...              ...     ...     ...   ...
# 444        Color Changer Pro [root]  PERSONALIZATION     4.5      69  951k
# 442             Watch Face BW Inter  PERSONALIZATION     3.1     112  8.8M
# 435            Little Magnet BT Pro            TOOLS     4.6     251  3.8M
# 432          BS Match Maker Premium            TOOLS     NaN       3  319k
# 378  Wolf of the BF:Commando MOBILE             GAME     3.4      32   27M
#
#      Installs  Type   Price Content Rating           Genres      Last Updated  \
# 179     10000  Paid  400.00       Everyone        Lifestyle       May 3, 2018
# 320      1000  Paid  399.99       Everyone          Finance     June 25, 2018
# 178     10000  Paid  399.99       Everyone        Lifestyle    March 11, 2018
# 318      5000  Paid  399.99       Everyone          Finance    March 22, 2018
# 315      1000  Paid  399.99           Teen          Finance  December 6, 2017
# ..        ...   ...     ...            ...              ...               ...
# 444      1000  Paid    0.99       Everyone  Personalization  January 12, 2017
# 442      1000  Paid    0.99       Everyone  Personalization    April 26, 2017
# 435      1000  Paid    0.99       Everyone            Tools    August 5, 2018
# 432        10  Paid    0.99       Everyone            Tools     July 10, 2018
# 378      1000  Paid    0.99   Everyone 10+           Arcade    March 23, 2017
#
#     Current Ver   Android Ver
# 179       1.0.1    4.1 and up
# 320       1.0.2    4.1 and up
# 178       1.0.0    4.4 and up
# 318         1.0    4.2 and up
# 315           2  4.0.3 and up
# ..          ...           ...
# 444        1.11    4.4 and up
# 442       2.1.7    4.3 and up
# 435       4.1.4    4.2 and up
# 432      1.11.2    5.0 and up
# 378     1.00.10    4.0 and up
#
# [756 rows x 13 columns]

# %%
sns.boxplot(data=Paid_Apps,y='Price').set_ylim(0,20)
# Out:
# (0.0, 20.0)

# %%
PlayStore_Set['Reviews'] = PlayStore_Set['Reviews'].apply(str_to_int)
PlayStore_Set['Review_Rating'] = PlayStore_Set.apply(lambda x: Review_Rating(x['Reviews'],x['Rating']),axis=1)
Top_10_Paid_Apps=PlayStore_Set.loc[PlayStore_Set['Type'] == 'Paid'].sort_values(by=['Review_Rating'],ascending=False).drop_duplicates(subset='App').reset_index(drop=True).head(10)

# %%
Top_10_Paid_Apps
# Out:
#                              App         Category  Rating  Reviews  \
# 0                      Minecraft           FAMILY     4.5  2376564
# 1                  Hitman Sniper             GAME     4.6   408292
# 2  Grand Theft Auto: San Andreas             GAME     4.4   348962
# 3              Where's My Water?           FAMILY     4.7   188740
# 4                    Bloons TD 5           FAMILY     4.6   190086
# 5                     True Skate           SPORTS     4.4   129409
# 6     Card Wars - Adventure Time           FAMILY     4.3   129603
# 7        Five Nights at Freddy's             GAME     4.6   100805
# 8          Beautiful Widgets Pro  PERSONALIZATION     4.2    97890
# 9            DraStic DS Emulator             GAME     4.6    87766
#
#                  Size  Installs  Type  Price Content Rating  \
# 0  Varies with device  10000000  Paid   6.99   Everyone 10+
# 1                 29M  10000000  Paid   0.99     Mature 17+
# 2                 26M   1000000  Paid   6.99     Mature 17+
# 3                 69M   1000000  Paid   1.99       Everyone
# 4                 94M   1000000  Paid   2.99       Everyone
# 5                 73M   1000000  Paid   1.99       Everyone
# 6                 23M   1000000  Paid   2.99   Everyone 10+
# 7                 50M   1000000  Paid   2.99           Teen
# 8                 14M   1000000  Paid   2.49       Everyone
# 9                 12M   1000000  Paid   4.99       Everyone
#
#                       Genres       Last Updated Current Ver  \
# 0  Arcade;Action & Adventure      July 24, 2018     1.5.2.1
# 1                     Action      July 12, 2018  1.7.110758
# 2                     Action     March 21, 2015        1.08
# 3         Puzzle;Brain Games       July 5, 2018      1.16.0
# 4                   Strategy      July 13, 2018        3.16
# 5                     Sports     August 4, 2018       1.5.1
# 6    Card;Action & Adventure  February 11, 2016      1.11.0
# 7                     Action   December 2, 2014        1.85
# 8            Personalization    August 24, 2016       5.7.8
# 9                     Action      July 19, 2016   r2.5.0.3a
#
#           Android Ver  Review_Rating
# 0  Varies with device     10694538.0
# 1          4.1 and up      1878143.2
# 2          3.0 and up      1535432.8
# 3          4.2 and up       887078.0
# 4        2.3.3 and up       874395.6
# 5        4.0.3 and up       569399.6
# 6        2.3.3 and up       557292.9
# 7          2.3 and up       463703.0
# 8          2.3 and up       411138.0
# 9          2.3 and up       403723.6

# %%
sns.catplot(data=Top_10_Paid_Apps,x='Rating',y='Price',hue='Category')

# %% [markdown]
# As we can see that, there are very few paid applications on Play store, lets see how many applications are

# %%
print(PlayStore_Set.groupby('Type')['App'].count())
# Out:
# Type
# Free    10039
# Paid      800
# Name: App, dtype: int64

# %% [markdown]
# ## Lets find out the percentage of paid and free applications available on Play store

# %%
FreeApps_percentage=(PlayStore_Set.groupby('Type')['App'].count()[0]/PlayStore_Set.groupby('Type')['App'].count().sum())*100
PaidApps_percentage=(PlayStore_Set.groupby('Type')['App'].count()[1]/PlayStore_Set.groupby('Type')['App'].count().sum())*100

# %%
print(FreeApps_percentage)
print(PaidApps_percentage)
# Out:
# 92.61924531783376
# 7.380754682166252

# %% [markdown]
# We another dataset called as Reviews_Set, we will now extract data from that set

# %%
Reviews_Set
# Out:
#                                App  \
# 0            10 Best Foods for You
# 1            10 Best Foods for You
# 2            10 Best Foods for You
# 3            10 Best Foods for You
# 4            10 Best Foods for You
# ...                            ...
# 64290  Houzz Interior Design Ideas
# 64291  Houzz Interior Design Ideas
# 64292  Houzz Interior Design Ideas
# 64293  Houzz Interior Design Ideas
# 64294  Houzz Interior Design Ideas
#
#                                        Translated_Review Sentiment  \
# 0      I like eat delicious food. That's I'm cooking ...  Positive
# 1        This help eating healthy exercise regular basis  Positive
# 2                                                    NaN       NaN
# 3             Works great especially going grocery store  Positive
# 4                                           Best idea us  Positive
# ...                                                  ...       ...
# 64290                                                NaN       NaN
# 64291                                                NaN       NaN
# 64292                                                NaN       NaN
# 64293                                                NaN       NaN
# 64294                                                NaN       NaN
#
#        Sentiment_Polarity  Sentiment_Subjectivity
# 0                    1.00                0.533333
# 1                    0.25                0.288462
# 2                     NaN                     NaN
# 3                    0.40                0.875000
# 4                    1.00                0.300000
# ...                   ...                     ...
# 64290                 NaN                     NaN
# 64291                 NaN                     NaN
# 64292                 NaN                     NaN
# 64293                 NaN                     NaN
# 64294                 NaN                     NaN
#
# [64295 rows x 5 columns]

# %% [markdown]
# ### We will look into types of reviews and understand the response ratio of sentiment response

# %%
Reviews_Set=Reviews_Set.loc[~Reviews_Set['Sentiment'].isnull()]
Review_Frame=Reviews_Set.groupby('Sentiment')['App'].count().reset_index()
Review_Frame
# Out:
#   Sentiment    App
# 0  Negative   8271
# 1   Neutral   5163
# 2  Positive  23998

# %%
sns.lineplot(data=Review_Frame,x='Sentiment',y='App')

# %% [markdown]
# ### Data provides the translated review which is a written response, here we have extracted most frequently used words for applications

# %%
PlayStore_1=PlayStore_Set.drop_duplicates(subset='App')
main_frame = pd.merge(PlayStore_1,Reviews_Set,on='App',how='inner')
main_frame
# Out:
#                                 App        Category  Rating  Reviews  \
# 0               Coloring book moana  ART_AND_DESIGN     3.9      967
# 1               Coloring book moana  ART_AND_DESIGN     3.9      967
# 2               Coloring book moana  ART_AND_DESIGN     3.9      967
# 3               Coloring book moana  ART_AND_DESIGN     3.9      967
# 4               Coloring book moana  ART_AND_DESIGN     3.9      967
# ...                             ...             ...     ...      ...
# 35929  A+ Gallery - Photos & Videos     PHOTOGRAPHY     4.5   223941
# 35930  A+ Gallery - Photos & Videos     PHOTOGRAPHY     4.5   223941
# 35931  A+ Gallery - Photos & Videos     PHOTOGRAPHY     4.5   223941
# 35932  A+ Gallery - Photos & Videos     PHOTOGRAPHY     4.5   223941
# 35933  A+ Gallery - Photos & Videos     PHOTOGRAPHY     4.5   223941
#
#                      Size  Installs  Type  Price Content Rating  \
# 0                     14M    500000  Free    0.0       Everyone
# 1                     14M    500000  Free    0.0       Everyone
# 2                     14M    500000  Free    0.0       Everyone
# 3                     14M    500000  Free    0.0       Everyone
# 4                     14M    500000  Free    0.0       Everyone
# ...                   ...       ...   ...    ...            ...
# 35929  Varies with device  10000000  Free    0.0       Everyone
# 35930  Varies with device  10000000  Free    0.0       Everyone
# 35931  Varies with device  10000000  Free    0.0       Everyone
# 35932  Varies with device  10000000  Free    0.0       Everyone
# 35933  Varies with device  10000000  Free    0.0       Everyone
#
#                           Genres      Last Updated         Current Ver  \
# 0      Art & Design;Pretend Play  January 15, 2018               2.0.0
# 1      Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2      Art & Design;Pretend Play  January 15, 2018               2.0.0
# 3      Art & Design;Pretend Play  January 15, 2018               2.0.0
# 4      Art & Design;Pretend Play  January 15, 2018               2.0.0
# ...                          ...               ...                 ...
# 35929                Photography    August 6, 2018  Varies with device
# 35930                Photography    August 6, 2018  Varies with device
# 35931                Photography    August 6, 2018  Varies with device
# 35932                Photography    August 6, 2018  Varies with device
# 35933                Photography    August 6, 2018  Varies with device
#
#               Android Ver  Review_Rating  \
# 0            4.0.3 and up         3771.3
# 1            4.0.3 and up         3771.3
# 2            4.0.3 and up         3771.3
# 3            4.0.3 and up         3771.3
# 4            4.0.3 and up         3771.3
# ...                   ...            ...
# 35929  Varies with device      1007734.5
# 35930  Varies with device      1007734.5
# 35931  Varies with device      1007734.5
# 35932  Varies with device      1007734.5
# 35933  Varies with device      1007734.5
#
#                                        Translated_Review Sentiment  \
# 0      A kid's excessive ads. The types ads allowed a...  Negative
# 1                                             It bad >:(  Negative
# 2                                                   like   Neutral
# 3                               I love colors inspyering  Positive
# 4                                                 I hate  Negative
# ...                                                  ...       ...
# 35929           Overall great app. Best gallery seen far  Positive
# 35930  Recommended, 100% love it, keep good work dev ...  Positive
# 35931                                       Too much ads  Positive
# 35932                                Just allow time ...   Neutral
# 35933                       It's good best gallery phone  Positive
#
#        Sentiment_Polarity  Sentiment_Subjectivity
# 0               -0.250000                1.000000
# 1               -0.725000                0.833333
# 2                0.000000                0.000000
# 3                0.500000                0.600000
# 4               -0.800000                0.900000
# ...                   ...                     ...
# 35929            0.475000                0.512500
# 35930            0.566667                0.733333
# 35931            0.200000                0.200000
# 35932            0.000000                0.000000
# 35933            0.850000                0.450000
#
# [35934 rows x 18 columns]

# %%
def list_words(index):
  sentence = main_frame.loc[index,'Translated_Review']
  lst=sentence.replace(',',"").replace('.','').split()
  l = []
  for i in lst:
    if len(i) > 3:     
      l.append(i)
  return l

# %%
list_words(0)
# Out:
# ["kid's", 'excessive', 'types', 'allowed', 'alone', 'kids']

# %%
df_name = pd.DataFrame()

# %%
for index,i in main_frame.iterrows():
  try:
      df_name = df_name.append({'Application':main_frame.loc[index,'App'],'Words':list_words(index)},ignore_index=True)
  except:
    continue

# %%
df_name
# Out:
#                         Application  \
# 0               Coloring book moana
# 1               Coloring book moana
# 2               Coloring book moana
# 3               Coloring book moana
# 4               Coloring book moana
# ...                             ...
# 35924  A+ Gallery - Photos & Videos
# 35925  A+ Gallery - Photos & Videos
# 35926  A+ Gallery - Photos & Videos
# 35927  A+ Gallery - Photos & Videos
# 35928  A+ Gallery - Photos & Videos
#
#                                                  Words
# 0      [kid's, excessive, types, allowed, alone, kids]
# 1                                                   []
# 2                                               [like]
# 3                           [love, colors, inspyering]
# 4                                               [hate]
# ...                                                ...
# 35924            [Overall, great, Best, gallery, seen]
# 35925      [Recommended, 100%, love, keep, good, work]
# 35926                                           [much]
# 35927                              [Just, allow, time]
# 35928               [It's, good, best, gallery, phone]
#
# [35929 rows x 2 columns]

# %%
df_Words=df_name.groupby('Application')
df_Words.first()
# Out:
#                                                                                                 Words
# Application
# 10 Best Foods for You                               [like, delicious, food, That's, cooking, food,...
# 11st                                                                         [Horrible, verification]
# 1800 Contacts - Lens Store                          [Great, hassle, free, order, contacts, call, r...
# 1LINE – One Line with One Touch                     [gets, there's, every, single, level, restart,...
# 2018Emoji Keyboard 😂 Emoticons Lite -sticker&gif    [Like, Version, Better, Where, Backspace, Besi...
# ...                                                                                               ...
# Hotels.com: Book Hotel Rooms & Find Vacation Deals  [Bookings, stopped, showing, Helpline, useless...
# Hotspot Shield Free VPN Proxy & Wi-Fi Security      [days, free, trial, asking, credit, card, Stup...
# Hotstar                                                                                     [running]
# Hotwire Hotel & Car Rental App                      [worthless, allow, information, would, went, h...
# Housing-Real Estate & Property                      [Incorrect, listings, agents, show, property, ...
#
# [816 rows x 1 columns]

# %%
df_4 = pd.DataFrame()

# %%
lst = ['dog','cat','dog','cat','dog','dog','men','men','men','men','bro','bro','bro','bro','bro','bro','bro','bro']
print(lst.count(max(lst,key=lst.count)),max(lst,key=lst.count))
# Out:
# 8 bro

# %%
for i in df_name.drop_duplicates(subset='Application')['Application']:
  l = []
  count = 0
  for word in df_Words.get_group(i)['Words']:
    for w in word:
      l.append(w)
  df_4 = df_4.append({'Name':i,'Highest Frequency': max(l,key=l.count)},ignore_index=True)

# %%
df_4.sort_values(by='Highest Frequency')
# Out:
#                                Name Highest Frequency
# 698            Adobe Acrobat Reader             Adobe
# 582                          Airbnb            Airbnb
# 498                 Amazon Shopping            Amazon
# 660        Google Handwriting Input           Android
# 54    Asana: organize team projects             Asana
# ..                              ...               ...
# 201    Citizens Bank Mobile Banking             works
# 466   Davis's Drug Guide for Nurses             would
# 608  Hotwire Hotel & Car Rental App             would
# 253   Down Dog: Great Yoga Anywhere              yoga
# 360      Disney Heroes: Battle Mode              your
#
# [816 rows x 2 columns]

# %%
data_1 = df_4.groupby('Highest Frequency').count().sort_values(by="Name",ascending=False).reset_index().head(10)
data_1
# Out:
#   Highest Frequency  Name
# 0              game   130
# 1              good    36
# 2              love    23
# 3              like    23
# 4             phone    19
# 5              news    16
# 6            people    15
# 7             Great    14
# 8              time    14
# 9            update    13

# %%
sns.lineplot(data=data_1,x='Highest Frequency',y='Name').set_ylabel('Counts')
# Out:
# Text(0, 0.5, 'Counts')
